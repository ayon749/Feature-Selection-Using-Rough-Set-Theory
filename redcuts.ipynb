# %%
import pandas as pd

# %%
dataset=pd.read_csv("sortedDataframe.csv")

# %%
dataset.head()
features=dataset.columns
features
dataset['id']=dataset.groupby(['Class', 'Age', 'Sex', 'Steriod', 'Antivirus', 'Fatigue', 'Malaise',
       'Anorexia', 'Liver big', 'Liver firm', 'Spleen palpable', 'Spiders',
       'Ascites', 'Varices', 'Bilirubin', 'Alk phosphate', 'Sgot', 'Albumin',
       'Protime', 'Histology']).cumcount()

dataset.sort_values(['Class', 'Age', 'Sex', 'Steriod', 'Antivirus', 'Fatigue', 'Malaise',
       'Anorexia', 'Liver big', 'Liver firm', 'Spleen palpable', 'Spiders',
       'Ascites', 'Varices', 'Bilirubin', 'Alk phosphate', 'Sgot', 'Albumin',
       'Protime', 'Histology']).head(10)
# Out:
#     Class  Age  Sex  Steriod  Antivirus  Fatigue  Malaise  Anorexia  \
# 63      1   33    1      1.0          2      1.0      1.0       2.0
# 74      1   38    1      1.0          2      2.0      2.0       2.0
# 18      1   39    1      1.0          1      1.0      1.0       2.0
# 64      1   42    1      1.0          1      1.0      1.0       2.0
# 84      1   43    1      2.0          2      1.0      2.0       2.0
# 51      1   44    1      1.0          2      1.0      1.0       2.0
# 82      1   46    1      2.0          2      1.0      1.0       1.0
# 77      1   47    1      2.0          2      1.0      1.0       2.0
# 61      1   47    1      2.0          2      1.0      1.0       2.0
# 57      1   47    1      2.0          2      2.0      2.0       2.0
#
#     Liver big  Liver firm ...  Spiders  Ascites  Varices  Bilirubin  \
# 63        2.0         2.0 ...      2.0      1.0      2.0        0.7
# 74        2.0         1.0 ...      2.0      2.0      2.0        0.4
# ...
